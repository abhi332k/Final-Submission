# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abhishek Yadav**
# >I am a chemical engineering student currently, but wish to be a data scientist in future

# %% [markdown]
# *I'm intersted in data science because I think it would be soon on the basic eligbilty fro eomployment due the rapid development we are witnessing the this field and it is applicable to literally every field so no running from it, but embrace and learn it*

# %% [markdown]
# ### My code is simply going to show the addition of 2 numbers

# %%
68+1
# Out:
# 69

# %% [markdown]
# *** Let's go
# >
# - Apple
# - Watermelon
# - Mangoes
# >
# 1. Beats
# 2. Bears
# 3. Battlefield Galatica
# >
# ![FeAixZ0VsAAhSOn.jpg](attachment:FeAixZ0VsAAhSOn.jpg)
